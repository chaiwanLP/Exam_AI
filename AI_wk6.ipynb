# %%
#pip install pandas

# %%
import pandas as pd 


data = [
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40]
]

column = ["ID","Name","Mid","Final"]
df = pd.DataFrame(data,columns=column)
print(df)
# Out:
#             ID   Name  Mid  Final
# 0  66011212124  night   20     40
# 1  66011212124  night   20     40
# 2  66011212124  night   20     40
# 3  66011212124  night   20     40

# %%
df_2 = pd.DataFrame(data)
print(df_2)
# Out:
#              0      1   2   3
# 0  66011212124  night  20  40
# 1  66011212124  night  20  40
# 2  66011212124  night  20  40
# 3  66011212124  night  20  40

# %%
print(df.head(2))
# Out:
#             ID   Name  Mid  Final
# 0  66011212124  night   20     40
# 1  66011212124  night   20     40

# %%
path = './Data/index.csv'
path2 = "./Data/dataxlsx.xlsx"
de_read = pd.read_csv(path)
data = pd.DataFrame(de_read)
de_read_2 = pd.read_excel(path2)

# %%
print(de_read)
# Out:
#   lek jui john duck
# 0      100 20 10 60

# %%
print(de_read_2[(de_read_2.Mid<=20)])
# Out:
#             ID   Name  Mid  Final
# 4  66011212124  night   12     16

# %%
de_3 = de_read_2.query('Mid > 40')
print(de_3)
# Out:
#             ID  Name  Mid  Final
# 0  66011212124   lek   88     38
# 1  66011212124   jui   81     38
# 2  66011212124  john   56     20
# 3  66011212124  dude   73     14
# 4  66011212124   ped   96     34
# 5  66011212124  duck   63     31
