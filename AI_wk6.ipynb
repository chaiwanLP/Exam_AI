# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 700.0 kB/s eta 0:00:00 0:00:01
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 17.7 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.2 pandas-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 


data = [
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40],
    ['66011212124',"night",20,40]
]

column = ["ID","Name","Mid","Final"]
df = pd.DataFrame(data,columns=column)
print(df)
# Out:
#             ID   Name  Mid  Final
# 0  66011212124  night   20     40
# 1  66011212124  night   20     40
# 2  66011212124  night   20     40
# 3  66011212124  night   20     40

# %%
df_2 = pd.DataFrame(data)
print(df_2)
# Out:
#              0      1   2   3
# 0  66011212124  night  20  40

# %%
print(df.head(2))
# Out:
#             ID   Name  Mid  Final
# 0  66011212124  night   20     40
# 1  66011212124  night   20     40

# %%
path = 'index.csv'
path2 = "index.xlsx"
de_read = pd.read_csv(path)
data = pd.DataFrame(de_read)
de_read_2 = pd.read_excel(path2)

# %%
print(de_read)
# Out:
#   Test kai cai mai
# 0     100 20 10 60

# %%
print(de_read_2[(de_read_2.Mid<=20)])
# Out:
#             ID   Name  Mid  Final
# 4  66011212124  night   12     16

# %%
de_3 = de_read_2.query('Mid > 40')
print(de_3)
# Out:
#             ID   Name  Mid  Final
# 0  66011212124  night   74     33
# 3  66011212124  night   87     14
# 5  66011212124  night   84     31
